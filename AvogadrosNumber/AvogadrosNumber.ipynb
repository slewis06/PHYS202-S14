# %% [markdown]
# # Final Project: Brownian motion and Avogadro's Number

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import requests
from StringIO import StringIO
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig = plt.figure()
labels = ['Blue', 'Yellow/White', 'Other']
fracs = [24, 82, 3]
plt.pie(fracs, labels=labels, colors=('b','y','r'), autopct='%1.1f%%', shadow=True)
plt.title('Elliptical Galaxies')

plt.show()

plt.figure()

fracs2 = [30, 7, 1]
plt.pie(fracs2, labels=labels, colors=('b','y','r'), autopct='%1.1f%%')
plt.title('Spiral Galaxies')
plt.show()

# %%
plt.pie?
