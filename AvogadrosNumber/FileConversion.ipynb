# %%
from PIL import Image
import requests
from StringIO import StringIO
import numpy as np
import Blobfinder2 as BF
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def TrackParticals1(P, tau, deltaP):    
    distancesLst = []
    for i in range(1, 8):
        pic1 = "AvogadrosData/Lewis_T000"+ str(i) + ".jpeg"
        pic2 = "AvogadrosData/Lewis_T000"+ str(i+1) + ".jpeg"
        #open two successive pictures
        im1 = Image.open(pic1)
        im2 = Image.open(pic2)

        #run BlobFinder to get a list of all bright objects in picture that includes
        #the mass and center of mass.
        LstOfBlobs = BF.BlobFinder(im1, tau)
        LstOfBlobs2 = BF.BlobFinder(im2, tau)
        im1.show()
        #Use getbeads to pick out the objects that have a mass above a given number.
        LstOfBeads = BF.getbeads(P,LstOfBlobs)
        LstOfBeads2 = BF.getbeads(P,LstOfBlobs2)
        #Now check the distance from all beads in pic1 to all beads in pic2
        for bead in LstOfBeads:
            temp = []
            for bead2 in LstOfBeads2:
                distance = bead.distanceTo(bead2)
                #only append distances less than deltaP and distances not equal to zero.
                #If a distance of zero is appended, the next if loop will keep appending
                #zero instead of the minimum float value. 
                if distance < deltaP and distance != 0.0:
                    temp.append(distance)
                else:
                    continue
            #Append to distancesLst, then break out of this for loop and move on to the next one.
            if len(temp) != 0:
                distancesLst.append(min(temp))
            else: continue
    return np.savetxt('distances2.txt', distancesLst, fmt='%.4f', header='List Of Distances')

# %%
TrackParticals1(25, 600, 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-adb248c3ed2b> in <module>()
# ----> 1 TrackParticals1(25, 600, 20)
#
# <ipython-input-6-92dc79a2e80b> in TrackParticals1(P, tau, deltaP)
#      10         #run BlobFinder to get a list of all bright objects in picture that includes
#      11         #the mass and center of mass.
# ---> 12         LstOfBlobs = BF.BlobFinder(im1, tau)
#      13         LstOfBlobs2 = BF.BlobFinder(im2, tau)
#      14         im1.show()
#
# /Users/lewis357/PHYS202-S14/AvogadrosNumber/Blobfinder2.py in BlobFinder(picture, tau)
#     111     """
#     112     float(tau)
# --> 113     monochrome(picture, tau)
#     114     #create list of blobs from picture.
#     115     LstOfBlobs = count(picture)
#
# /Users/lewis357/PHYS202-S14/AvogadrosNumber/Blobfinder2.py in monochrome(picture, threshold)
#      50     for x in range(xsize):
#      51         for y in range(ysize):
# ---> 52             r,g,b = temp[x,y]
#      53             if r+g+b <= threshold:
#      54                 temp[x,y] = black
#
# TypeError: 'int' object is not iterable

# %%
np.loadtxt('distances2.txt')
#see what it looks like
# !cat 'distances2.txt'
# Out:
# # List Of Distances
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 18.0000
# 18.0000
# 1.0000
# 1.0000
# 4.1231
# 3.0000
# 1.0000
# 1.0000
# 1.0000
# 11.1803
# 1.0000
# 1.0000
# 2.2361
# 1.0000
# 19.8494
# 1.0000
# 19.8494
# 1.0000
# 1.4142
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 2.0000
# 14.8661
# 1.0000
# 2.0000
# 14.8661
# 1.4142
# 1.4142
# 2.0000
# 2.2361
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 1.4142
# 16.4012
# 16.4012
# 2.2361
# 1.0000
# 1.0000
# 2.2361
# 1.4142
# 1.0000
# 1.4142
# 1.0000
# 1.0000
# 2.2361
# 1.0000
# 1.0000
# 1.0000
# 16.4012
# 19.7990
# 16.4012
# 1.4142
# 3.0000
# 1.4142
# 1.0000
# 19.2354
# 4.1231
# 2.2361
# 1.0000
# 1.0000
# 1.0000
# 3.0000
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 1.4142
# 1.0000
# 1.4142
# 1.0000
# 1.4142
# 1.0000
# 12.6491
# 19.1050
# 18.0000
# 8.2462
# 1.0000
# 2.0000
# 1.4142
# 1.0000
# 1.0000
# 1.0000
# 10.1980
# 1.0000
# 11.1803
# 1.0000
# 1.0000
# 11.1803
# 19.8494
# 1.0000
# 19.8494
# 1.0000
# 2.0000
# 12.6491
# 12.0416
# 1.0000
# 1.4142
# 1.0000
# 1.0000
# 14.8661
# 2.2361
# 2.0000
# 14.8661
# 1.0000
# 1.0000
# 1.0000
# 4.1231
# 1.0000
# 1.0000
# 1.0000
# 1.4142
# 1.4142
# 1.0000
# 14.1421
# 1.0000
# 1.0000
# 1.0000
# 15.8114
# 1.0000
# 1.0000
# 1.4142
# 1.0000
# 10.4403
# 1.0000
# 2.0000
# 1.0000
# 2.0000
# 1.0000
# 1.4142
# 15.6205
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 2.0000
# 1.4142
# 1.0000
# 1.0000
# 3.0000
# 1.0000
# 2.2361
# 1.4142
# 1.0000
# 18.3848
# 1.4142
# 3.6056
# 14.0000
# 1.0000
# 1.4142
# 1.4142
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 8.2462
# 1.4142
# 1.0000
# 11.1803
# 1.4142
# 1.0000
# 11.1803
# 19.8494
# 1.0000
# 19.8494
# 1.0000
# 12.0416
# 13.0000
# 12.0416
# 2.2361
# 1.4142
# 14.8661
# 1.0000
# 1.0000
# 15.8114
# 14.8661
# 1.4142
# 1.4142
# 2.2361
# 19.4165
# 10.7703
# 2.0000
# 1.4142
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 1.4142
# 15.8114
# 15.8114
# 1.0000
# 1.0000
# 1.4142
# 9.0554
# 2.2361
# 1.0000
# 2.0000
# 1.0000
# 18.3576
# 1.4142
# 16.4012
# 1.0000
# 1.0000
# 1.0000
# 2.2361
# 1.0000
# 1.0000
# 19.0263
# 1.0000
# 1.0000
# 1.0000
# 1.0000
# 1.4142
# 1.4142
# 19.2354
# 8.0000
# 10.0000
# 1.0000
# 1.0000
# 19.2354
# 1.4142
# 1.0000
# 1.0000

# %%
def AvogadrosNumberEstimate(distancefile):
    """
    This function converts all the pixel distances to meters, uses this to find the 
    'self diffusion constant' D, estimates the Boltzmann constant k using the
    Stokes-Einstein relation, then calculates Avogadros number by dividing the gas
    constant by k.
    """
    r = 0 #initialize r
    conversion = 0.175e-6 #meters/pixel
    eta = 9.125e-4 #viscosity of water, N*s/(m^2)
    rho = 0.5e-6 #radius of bead, m
    R = 8.31457 #Gas constant, J/(K*mol)
    T = 297 #Room temperature, K
    dt = 0.25 #time step, s
    
    #find the sum of all converted distances from the distance 
    #file squared to put through equation given.
    for dist in np.loadtxt(distancefile):
        r += (dist*conversion)**2

    #self diffusion constant estimation:
    D = (r/(2*len(np.loadtxt(distancefile))))/(2*dt)
    
    #Boltzmann constant estimation:
    k = (6*D*np.pi*eta*rho)/T #m^2kg/Ks^2
    
    #Avogadros number estimation:
    Na = R/k 
    return Na

# %%
print "My Avogadros Number Estimate is: %.4e" %(AvogadrosNumberEstimate('distances2.txt'))
print "Percent error = %.4f" %abs(((AvogadrosNumberEstimate('distances2.txt')-6.0221413e23)/6.0221413e23)*100)
# Out:
# My Avogadros Number Estimate is: 1.6095e+23
# Percent error = 73.2733
