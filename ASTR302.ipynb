# %% [markdown]
# # Galaxy Zoo Final Project

# %% [markdown]
# Hypothesis:

# %%
# %pylab inline
import matplotlib.pyplot as plt

fig = plt.figure()
labels = ['Blue', 'Yellow/White', 'Other']
fracs = [20, 92, 3]
plt.pie(fracs, labels=labels, colors=('b','y','r'), autopct='%1.1f%%', shadow=True)
plt.title('Elliptical Galaxies')

plt.show()

plt.figure()

fracs2 = [25, 5, 1]
plt.pie(fracs2, labels=labels, colors=('b','y','r'), autopct='%1.1f%%', shadow=True)
plt.title('Spiral Galaxies')
plt.show()

plt.figure()

labels2 = ['Elliptical','Spiral','Irregular']
fracs3 = [109,37,9]
plt.pie(fracs3, labels=labels2, autopct='%1.1f%%', shadow=True)
plt.title('Total Number of Galaxies Sampled: 155')
plt.show()


fracs4 = [45,97,4]
plt.pie(fracs4, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('Total Number of Galaxies Sampled: 155')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
