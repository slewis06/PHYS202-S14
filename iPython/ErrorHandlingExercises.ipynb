# %% [markdown]
# # Error Handling Exercises

# %% [markdown]
# **1.** Find a partner. Choose a driver and a navigator. The driver should copy their Battleship code to a cell in the driver's ErrorHandlingExercises notebook. The driver should explain to the navigator the basics of how their program works. Work together to add some error handling to the program. Include a markdown cell identifying the driver and navigator. When you are done, switch roles and let the navigator be the driver and vice versa. At the end you should both have a Battleship program that includes some error handling.

# %% [markdown]
# Driver: Sean Lewis
#
# Navigator: Conrad Pearson

# %%
from ipythonblocks import BlockGrid
from random import randint
# %pylab inline

print "Battleship! Guess a row and column, try and sink the ship!"

#Creates the board, 15 x 15 and a light blue color.
board = BlockGrid(15,15, fill=(173, 216, 230))
board.show()

#Generates a random row for the ship to occupy.
def random_row(board):
    return randint(2, (board.width - 1))

#Generates a random column for the ship to occupy.
def random_col(board):
    return randint(0, (board.height - 1))

#This stores the value of the random square on the board in two variables.
#Then, the ship is expanded in length by defining the variable ship_row1.
ship_row = random_row(board)
ship_col = random_col(board)
ship_row1 = ship_row - 1

#Initialize turn value and allow user to input number of desired turns.
turn = 1
try:
    number_of_turns = int(raw_input("Number of turns:"))
except ValueError as err:
    print "Oops, try again, you did not enter a number!"
    try:
        number_of_turns = int(raw_input("Number of turns:"))
    except ValueError as err:
        print "Okay fine, your number of turns is 5."
        number_of_turns = 5

for turn in range(number_of_turns):
    #Allow user to guess row and column values.
    try:
        guess_row = int(raw_input("Guess Row:"))
        guess_col = int(raw_input("Guess Col:"))
    except ValueError as err:
        print "You didn't enter a number!"
        
        continue
    
    #Turns the guessed block red if the guessed block is equal to the randomly generated one.
    if guess_row == ship_row and guess_col == ship_col:
        board[guess_row, guess_col].red = 255
        board[guess_row, guess_col].blue = 0
        board[guess_row, guess_col].green = 0
        print "You hit my battleship!"
    
        #If, after guessing a correct block, both are red, then you win the game!
        if board[ship_row, ship_col].red == 255 and board[ship_row1, ship_col].red == 255:
            print "You've won! You sunk my battleship!"
            board.show()
            break
            
    #This is the same process as the if loop above but now for ship_row1        
    elif guess_row == ship_row1 and guess_col == ship_col:    
        board[ship_row1, guess_col].red = 255
        board[ship_row1, guess_col].blue = 0
        board[ship_row1, guess_col].green = 0
        print "You hit my battleship!"
        
        if board[ship_row, ship_col].red == 255 and board[ship_row1, ship_col].red == 255:
            print "You've won! You sunk my battleship!"
            board.show()
            break
            
    #If the player guesses something that is out of the board, they receive this message.        
    elif (guess_row < 0 or guess_row > board.width) or (guess_col < 0 or \
        guess_col > board.height):
            print "Oops, that's not even in the ocean. Try again!"
            
    #If the player makes a guess, but the block is already yellow or red, they will be promted telling them so.     
    elif board[guess_row, guess_col].red == 255 or board[guess_row, guess_col].green == 255:
        print "You guessed that one already."
    
    #If none of the above loops can be entered, that means the player missed the battleship.    
    else:
        print "You missed my battleship!"
        board[guess_row, guess_col] = (254, 255, 0)
    
    #This if loop determines when the game will finish based on the player's turns, and changes any unhit ship blocks to dark red.
    if turn == number_of_turns - 1:
        print "Game Over"
        if board[ship_row, ship_col] != (255, 0, 0):
            board[ship_row, ship_col] = (139, 0, 0)
        else:
            board[ship_row, ship_col] = (255, 0, 0)
        if board[ship_row1,ship_col] != (255, 0, 0):
            board[ship_row1,ship_col] = (139, 0, 0)
        else:
            board[ship_row1,ship_col] = (255, 0, 0)
  
    print "Turn", turn + 1
    board.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Battleship! Guess a row and column, try and sink the ship!
# WARNING: pylab import has clobbered these variables: ['randint']
# `%matplotlib` prevents importing * from pylab and numpy
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks0d32c85d-94ad-4734-abc1-c41f74769729 td {border: 1px solid white;}</style><table id="blocks0d32c85d-94ad-4734-abc1-c41f74769729" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 10]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 13]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 14]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 10]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 13]&#10;Color: (173, 216, 230)" style="wi ...
# Number of turns:f
# Oops, try again, you did not enter a number!
# Number of turns:f
# Okay fine, your number of turns is 5.
# Guess Row:3
# Guess Col:4
# You missed my battleship!
# Turn 1
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks2fd90e89-eb86-44b4-99c8-427ffdc056e2 td {border: 1px solid white;}</style><table id="blocks2fd90e89-eb86-44b4-99c8-427ffdc056e2" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 10]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 13]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 14]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 10]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 13]&#10;Color: (173, 216, 230)" style="wi ...
# Guess Row:2
# Guess Col:1
# You missed my battleship!
# Turn 2
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks30a2ba07-8efa-454a-9992-9157e4c273f8 td {border: 1px solid white;}</style><table id="blocks30a2ba07-8efa-454a-9992-9157e4c273f8" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 10]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 13]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 14]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 10]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 13]&#10;Color: (173, 216, 230)" style="wi ...
# Guess Row:
# You didn't enter a number!
# Guess Row:3
# Guess Col:4
# You guessed that one already.
# Turn 4
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksc0b496a5-0912-432b-a1fe-73d6b024ab5f td {border: 1px solid white;}</style><table id="blocksc0b496a5-0912-432b-a1fe-73d6b024ab5f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 10]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 13]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 14]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 10]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 13]&#10;Color: (173, 216, 230)" style="wi ...
# Guess Row:5
# Guess Col:4
# You missed my battleship!
# Game Over
# Turn 5
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks3ad28e2f-6f70-4ce3-bce0-78ef2305cf35 td {border: 1px solid white;}</style><table id="blocks3ad28e2f-6f70-4ce3-bce0-78ef2305cf35" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 10]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 13]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 14]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 10]&#10;Color: (139, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(139, 0, 0);"></td><td title="Index: [1, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 13]&#10;Color: (173, 216, 230)" style="width: 20p ...

# %% [markdown]
# **2.** Here is a function which takes a filename, opens the file, reads the result, closes the file, and returns the contents. It should look something like this:

# %%
def read_all_from_file(filename):
    f = open(filename)
    contents = f.read()
    f.close()
    return contents

# %% [markdown]
# Use runtime error handling concepts to improve this function, so that it does the following:
#
# * raises an informative custom error if the file doesn't exist
# * uses try, except, else, and/or finally to safely return the file's contents & close the file if necessary.
# * add a keyword safe which defaults to False. If the function is called with safe=True, then return an empty string if the file doesn't exist.

# %%
def read_all_from_file(filename, safe=False):
    try:
        f = open(filename)
    except NameError as err:
        print "That file name does not exist!"
        if safe == True:
            return ""
    except IOError as err:
        print "That file does not exist!"
        if safe == True:
            return ""
    except:
        print "Unknown Error"
        if safe == True:
            return ""
    else:
        contents = f.read()
        f.close()
        return contents

# %%
read_all_from_file('notafile.txt', True)
# Out:
# That file does not exist!
# ''
