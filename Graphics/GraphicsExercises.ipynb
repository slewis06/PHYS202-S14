# %% [markdown]
# # Graphics Exercises

# %%
#Import all necessary things.

# %pylab inline
from scipy import misc
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **1.** Have a look at the Matplotlib gallery, find a cool looking figure, use the %loadpy magic we used before to copy the code into the box below, and modify it. Note that some of the examples might require packages that are not installed on your machine (in particular those that make maps) - if this is the case, pick another example for the purposes of this exercise.
#
# Type %loadpy and then the URL of the py file containing the code, and it will automatically copy it into a cell below. Run the cell with the code to see the figure.

# %%
#Use loadpy magic to load the file used to create a sample in the Matplotlib gallery.

# %loadpy 'http://matplotlib.org/mpl_examples/lines_bars_and_markers/fill_demo.py'

# %%
"""
Simple demo of the fill function.
"""
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0, 1)
y = np.sin(4 * np.pi * x) * np.exp(-5 * x)

plt.fill(x, y, 'r')
plt.grid(True)
plt.show()

# %% [markdown]
# **2.** Download the linked file called sunspots.txt, which contains the observed number of sunspots on the Sun for each month since January 1749. The file contains two columns of numbers, the first being the month and the second being the sunspot number. **(See note below∗ for how to download it.)**
#
# **(a)** Write some code that reads in the data and makes a graph of sunspots as a function of time. Format the x-axis labels to show every 25th year starting with 1750 e.g. (1750, 1775, 1800, 1825, 1850, etc.), instead of sunspot number. Be sure to think about how to make this graph publication quality, i.e. it should have labels, a legend, and customized (i.e. NOT default) color and data representation choices.

# %%
#I '!cat'ed sunspots.txt just to see exactly how the data was oriented.
# !cat 'sunspots.txt'
# Out:
# 0	58.0
# 1	62.6
# 2	70.0
# 3	55.7
# 4	85.0
# 5	83.5
# 6	94.8
# 7	66.3
# 8	75.9
# 9	75.5
# 10	158.6
# 11	85.2
# 12	73.3
# 13	75.9
# 14	89.2
# 15	88.3
# 16	90.0
# 17	100.0
# 18	85.4
# 19	103.0
# 20	91.2
# 21	65.7
# 22	63.3
# 23	75.4
# 24	70.0
# 25	43.5
# 26	45.3
# 27	56.4
# 28	60.7
# 29	50.7
# 30	66.3
# 31	59.8
# 32	23.5
# 33	23.2
# 34	28.5
# 35	44.0
# 36	35.0
# 37	50.0
# 38	71.0
# 39	59.3
# 40	59.7
# 41	39.6
# 42	78.4
# 43	29.3
# 44	27.1
# 45	46.6
# 46	37.6
# 47	40.0
# 48	44.0
# 49	32.0
# 50	45.7
# 51	38.0
# 52	36.0
# 53	31.7
# 54	22.0
# 55	39.0
# 56	28.0
# 57	25.0
# 58	20.0
# 59	6.7
# 60	0.0
# 61	3.0
# 62	1.7
# 63	13.7
# 64	20.7
# 65	26.7
# 66	18.8
# 67	12.3
# 68	8.2
# 69	24.1
# 70	13.2
# 71	4.2
# 72	10.2
# 73	11.2
# 74	6.8
# 75	6.5
# 76	0.0
# 77	0.0
# 78	8.6
# 79	3.2
# 80	17.8
# 81	23.7
# 82	6.8
# 83	20.0
# 84	12.5
# 85	7.1
# 86	5.4
# 87	9.4
# 88	12.5
# 89	12.9
# 90	3.6
# 91	6.4
# 92	11.8
# 93	14.3
# 94	17.0
# 95	9.4
# 96	14.1
# 97	21.2
# 98	26.2
# 99	30.0
# 100	38.1
# 101	12.8
# ...

# %%
#load sunspots.txt using np.loadtxt and assign it to a variable.
x = np.loadtxt('sunspots.txt')

#define months as every row in the first column of the data.
months = x[:,0]

#We dont want months, we want the year, starting from 1749.
#So, by dividing each value in months by 12 and adding it to 1749, we can keep track of what year it is!
years = months/12. + 1749

#The number of sunspots is defined as every row in the 2nd column.
sunspots = x[:,1]

#Here I define a plot, label the x and y axes, and give it a title.
fig, ax = plt.subplots(1, 1)
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Number of Sunspots', fontsize=14)
ax.set_title('Sunspots', fontsize=20)

#I want the graph to start at 1749, as it is the first year with available data.
#However, to make it look nice, I set the ticks on the x-axis to go from 1750 to 2050 in even steps of 25 years.
plt.xlim(1749,2025)
plt.xticks(linspace(1750, 2025, 12))

#Here I actually plot the data and manipulate it to look nice.
plt.plot(years,sunspots, 'o', markersize=2.5, color="DarkOrange", linewidth = 0.5, label='# of sunspots');

#Here I plot the running average, which is defined in part b.
plt.plot(years,avg, label = 'average')

#And finally I place the legend at the position Python thinks is best.
plt.legend(loc='best');

# %% [markdown]
# **(b)** Now add code to calculate the running average of the data. Plot both the original data and the running average on the same graph, only over the range covered by the first 1000 data points.

# %%
#The above graph will produce an error, saying 'avg not defined', however,
#once this cell is run, the graph will display the running average.

def movingaverage(interval, window_size):
    window= numpy.ones(int(window_size))/float(window_size)
    return numpy.convolve(interval, window, 'same')

# %%
avg = movingaverage(sunspots, 1000)

# %% [markdown]
# See part (a) for combined graph

# %% [markdown]
# **3.** Download the linked file called stars.txt, which contains the temperatures and magnitudes of several thousand stars in the Milky Way near our solar system. You will use this data to construct a scatter plot of stellar magnitude (logarithm of brightness) vs. temperature (in Kelvin), called a Hertzsprung-Russell diagram, after the astronomers who first plotted such data this way. The diagram is one of the fundamental tools of stellar astrophysics. For historical reasons, H-R diagrams are normally plotted with both the magnitude and temperature axes decreasing to the right/up rather than increasing.
#
# **(a)** Read in the data from stars.txt and plot the data as is, with magnitude and temperature increasing in the usual way. Add labels and format your graph as publication quality.

# %%
#Load up the file.
x = np.loadtxt('stars.txt')

#Set the stars' magnitudes to the entire 2nd column.
magnitude = x[:,1]

#Temperature is the entire 1st column.
temperature = x[:,0]

#Here I create the plot, label the axes, and set a title.
fig, ax = plt.subplots(1, 1)
ax.set_xlabel('Temperature (K)', fontsize=14)
ax.set_ylabel('Magnitude (mag)', fontsize=14)
ax.set_title('Hertzsprung-Russel of Stellar Neighboors', fontsize=20)

#Now I plote the actual data, manipulate it so that it looks nice, and place the legend.
plt.plot(temperature, magnitude, 'o', markersize=3, color="Orange", label='Stars');
plt.legend(loc = 'lower left');

# %% [markdown]
# **(b)** Now use the xlim() and ylim() commands to flip your graph so that it is a correct H-R diagram. There are several regions of the diagram where stars seem to cluster. Have a look at the wikipedia entry on H-R diagrams to find out what each of these regions are called and add some annotations to your graph to identify them.

# %%
#Everything here is copied from part a.
#---------------------------------
x = np.loadtxt('stars.txt')
magnitude = x[:,1]
temperature = x[:,0]

fig, ax = plt.subplots(1, 1)
ax.set_xlabel('Temperature (K)', fontsize=14)
ax.set_ylabel('Magnitude (mag)', fontsize=14)
ax.set_title('Hertzsprung-Russel of Stellar Neighboors', fontsize=20)

plt.plot(temperature, magnitude, 'o', markersize=3, color="Orange", label='Stars');
plt.legend(loc = 'lower left');
#----------------------------------
#New code:

#Here I define the x and y limits such that the graph is oriented as the problem asks for.
plt.ylim(20,-5)
plt.xlim(16000,0)

#And finally I place little lables at specific points to make the graph more informative.
plt.annotate('Supergiants', xy=(2000,0), xytext=(3730,0));
plt.annotate('Giants', xy=(3000,6), xytext=(3000,6));
plt.annotate('Main Sequence', xy=(11000,5), xytext=(11000,5));
plt.annotate('White Dwarfs', xy=(10000,15), xytext=(10000,15));

# %% [markdown]
# **4.** Make a 3D plot of the function G(x,y)=e^(−x^2−y^2) over the range -6 <(x,y)< 6 using 51 bins in x and 51 bins in y.

# %%
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')
X = np.arange(-6, 6, 0.255)
Y = np.arange(-6, 6, 0.255)
#Re-factor the x,y arrays to be a 2-D grid
X, Y = np.meshgrid(X, Y)
R = (-X**2 - Y**2)
G = np.exp(R)
surf = ax.plot_surface(X, Y, G, rstride=1, cstride=1, cmap=cm.jet,
        linewidth=0, antialiased=False)
ax.set_zlim3d(-1.01, 1.01);

# %% [markdown]
# **5.** Determine the electric potential for a quadrupole consisting of
#
# q1 = -1.0 nC at (-2 m, 0 m)
#
# q2 = -1.0 nC at (+2 m, 0 m)
#
# q3 = +1.0 nC at (0 m, -2 m)
#
# q4 = +1.0 nC at (0 m, +2 m)

# %% [markdown]
# **(a)** Make a surface plot on the range -4 <(x,y)< 4 using 101 bins in x and 101 bins in y. In this case, do not let k = q = d = 1. Use dimensionful quantities and compute the value of the potential in volts.
#
# Recall k = 8.9875517873681764 × 10^9 N⋅ m^2/C^2.

# %%
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm

k = 8.9875517873681764 * (10**9)
q = 1.0 * 10**(-9)


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')
X = np.arange(-4, 4, 8./101)
Y = np.arange(-4, 4, 8./101)

X, Y = np.meshgrid(X, Y)

r1 = np.sqrt(Y**2 + (X+2)**2)
r2 = np.sqrt(Y**2 + (X-2)**2)
r3 = np.sqrt((Y+2)**2 + X**2)
r4 = np.sqrt((Y-2)**2 + X**2)

#Re-factor the x,y arrays to be a 2-D grid

Z = k*q*((-1/r1) - (1/r2) + (1/r3) + (1/r4))
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.jet,
        linewidth=0, antialiased=False)

# %% [markdown]
# **(b)** Now make a contour plot of the same data, with appropriate contour levels to see the shape of the potential.

# %%
k = 8.9875517873681764 * (10**9)
q = 1.0 * 10**(-9)

X = np.arange(-4, 4, 8./101)
Y = np.arange(-4, 4, 8./101)

X, Y = np.meshgrid(X, Y)

r1 = np.sqrt(Y**2 + (X+2)**2)
r2 = np.sqrt(Y**2 + (X-2)**2)
r3 = np.sqrt((Y+2)**2 + X**2)
r4 = np.sqrt((Y-2)**2 + X**2)

Z = k*q*((-1/r1) - (1/r2) + (1/r3) + (1/r4))

V = [-100, -50, -25, -10, -5, -1.5, 0, 1.5, 5, 10, 25, 50, 100]
plt.figure();
Cont = plt.contour(X, Y, Z, V);
plt.clabel(Cont, inline=1, fontsize=10);

# %% [markdown]
# **6.** Find a juicy equation in a textbook from one of your classes and use LATEX to typeset it in a markdown cell. Include an explanation of what the equation is for.

# %% [markdown]
# \begin{equation}
# Z = \frac{\Delta\lambda}{\lambda_{rest}} = \sqrt{{\frac{1 + \frac{v}{c}}{1 - \frac{v}{c}}}} - 1
# \end{equation}

# %% [markdown]
# This equation defines the relativistic redshift parameter (Z) as a ratio between the change in wavelength (due to red/blue shift) and the wavelength of light emitted by the object at rest. The ratio is also described by the business on the far right of the equation above where v = velocity and c = the speed of light.
#
# The above equation is used in astronomy to give astronomers an idea of how fast a stellar object is coming towards us (blueshift) or moving away from us (redshift). If Z is positive, then the object is redshifted; if Z is negative, it is blueshifted. The actual value of Z tells astronomers the rate at which the object is approaching or receding. Z has no limit to how large (positive or negative) it can be. The larger Z is, the closer the object is moving to the speed of light (without ever passing it, of course)
